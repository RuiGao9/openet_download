# %% [markdown]
# - How to install this: pip install "git+https://github.com/RuiGao9/openet_download.git"
# - Local install when testing the code `pip install -e .`
# - Please select the model type below for the parameter listed as `model'
#     - `Ensemble`
#     - `DisALEXI`
#     - `eeMETRIC`
#     - `geeSEBAL`
#     - `PT-JPL`
#     - `SIMS`
#     - `SSEBop`

# %%
from openet_download import download_et_timeseries

### ====== User Inputs === ###
YOUR_API_KEY = "APPLY FOR AN API KEY AT https://openetdata.org/"
model = "Ensemble"
longitude = -120.414164
latitude = 37.375004
interval = "monthly"
dir_out = r"C:\GitHub\openet_download\outputs"
start_date = "2024-10-01"
end_date = "2025-09-30"
plot = True
show_plot = True

### ====== Keep Defaults Below === ###
out = download_et_timeseries(
    lon=longitude,
    lat=latitude,
    start=start_date,
    end=end_date,
    interval=interval,
    model = model,
    out_dir=dir_out,
    api_key=YOUR_API_KEY,
    plot=plot,
    show_plot=show_plot,
)
print(out["csv"], out["figure"])
print(out["data"].head())
# Out:
# C:\GitHub\openet_download\outputs\OpenET_Ensemble_ET_monthly_2024-10-01_to_2025-09-30_lon-120.41416_lat37.37500.csv C:\GitHub\openet_download\outputs\OpenET_Ensemble_ET_monthly_2024-10-01_to_2025-09-30_lon-120.41416_lat37.37500.png
#         date  ET_mm
# 0 2024-10-01    1.0
# 1 2024-11-01   10.0
# 2 2024-12-01   14.0
# 3 2025-01-01   24.0
# 4 2025-02-01   43.0
